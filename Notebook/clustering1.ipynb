# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle

with open('/content/drive/My Drive/Upwork/Unsupervised_learning/x_train_hog.pkl', 'rb') as handle:
    X_train = pickle.load(handle)

with open('/content/drive/My Drive/Upwork/Unsupervised_learning/x_test_hog.pkl', 'rb') as handle:
    X_test = pickle.load(handle)

# %%
'''
import pickle

with open('/content/drive/My Drive/Upwork/Unsupervised_learning/x_train.pkl', 'rb') as handle:
    X_train = pickle.load(handle)

with open('/content/drive/My Drive/Upwork/Unsupervised_learning/x_test.pkl', 'rb') as handle:
    X_test = pickle.load(handle)
'''

# %%
import tensorflow as tf
import tensorflow.keras as K
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def preprocess_data(X, Y):
    """
    function that pre-processes the CIFAR10 dataset as per
    densenet model requirements for input images
    labels are one-hot encoded
    """
    X = K.applications.densenet.preprocess_input(X)
    Y = K.utils.to_categorical(Y)
    return X, Y

(x_train, y_train), (x_test, y_test) = K.datasets.cifar10.load_data()
# preprocess the data using the application's preprocess_input method and convert the labels to one-hot encodings
x_train, y_train = preprocess_data(x_train, y_train)
x_test, y_test = preprocess_data(x_test, y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
X_test.shape
# Out:
# (10000, 324)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=42, max_iter=1000, algorithm='elkan').fit(X_train)

# %%
kmeans.n_iter_
# Out:
# 109

# %%
kmeans.score(X_test)
# Out:
# -46541752.0

# %%
preds=kmeans.predict(X_test)
preds.shape
# Out:
# (10000,)

# %%
y1=np.argmax(y_test,axis=1)
y1.shape
# Out:
# (10000,)

# %%
preds[:10]
# Out:
# array([2, 6, 8, 6, 5, 7, 4, 0, 0, 5], dtype=int32)

# %%
y1[:10]
# Out:
# array([3, 8, 8, 0, 6, 6, 1, 6, 3, 1])

# %%
correct=0
mapping={}

for i,p in enumerate(preds):
  try:
    if p==mapping[p]:
      correct+=1
  except:
    mapping[p]=y1[i]

print(correct*100/len(y1))
# Out:
# 9.14

# %%
from collections import Counter

correct=0
mapping={}

for val in set(y1):
  inds=[i for i in range(len(y1)) if y1[i]==val] # all indices
  p=preds[inds]
  y2=y1[inds]
  counts=dict(Counter(p))

  print("y2: ", y2[:3])
  print("counts: ", counts)
  print("----------------")
  #break
# Out:
# y2:  [0 0 0]
# counts:  {6: 289, 1: 103, 8: 171, 4: 72, 0: 65, 9: 166, 7: 61, 3: 22, 5: 23, 2: 28}
# ----------------
# y2:  [1 1 1]
# counts:  {4: 39, 5: 74, 9: 255, 6: 136, 7: 121, 8: 254, 0: 26, 2: 82, 1: 10, 3: 3}
# ----------------
# y2:  [2 2 2]
# counts:  {3: 184, 0: 187, 2: 81, 8: 73, 4: 190, 9: 58, 5: 66, 1: 109, 7: 37, 6: 15}
# ----------------
# y2:  [3 3 3]
# counts:  {2: 176, 0: 98, 3: 310, 7: 69, 5: 128, 4: 75, 1: 72, 9: 41, 8: 24, 6: 7}
# ----------------
# y2:  [4 4 4]
# counts:  {3: 155, 7: 58, 5: 181, 1: 160, 4: 66, 8: 51, 2: 187, 0: 80, 9: 50, 6: 12}
# ----------------
# y2:  [5 5 5]
# counts:  {5: 117, 4: 61, 3: 407, 9: 15, 7: 41, 2: 151, 0: 91, 1: 104, 6: 2, 8: 11}
# ----------------
# y2:  [6 6 6]
# counts:  {5: 164, 7: 26, 0: 205, 2: 211, 4: 180, 8: 49, 9: 45, 3: 63, 1: 55, 6: 2}
# ----------------
# y2:  [7 7 7]
# counts:  {3: 150, 2: 217, 5: 230, 8: 28, 1: 165, 9: 21, 0: 64, 4: 60, 6: 6, 7: 59}
# ----------------
# y2:  [8 8 8]
# counts:  {6: 301, 8: 164, 0: 21, 9: 155, 7: 234, 1: 52, 3: 11, 4: 29, 5: 15, 2: 18}
# ----------------
# y2:  [9 9 9]
# counts:  {7: 329, 2: 146, 1: 110, 3: 45, 0: 30, 9: 64, 4: 21, 6: 66, 8: 90, 5: 99}
# ----------------

# %%
#HOG sift
mapping={
    0:8,
    1:9,
    2:4,
    3:2,
    4:1,
    5:3,
    6:0,
    7:5,
    8:6,
    9:7
}
correct=171+255+190+176+160+407+205+230+301+329
print("accuracy: ", correct*100/len(y1))
# Out:
# accuracy:  24.24

# %%
#dense net
mapping={
    0:6,
    1:5,
    2:7,
    3:9,
    4:4,
    5:0,
    6:3,
    7:8,
    8:1,
    9:2
}
correct=699+905+643+791+497+429+636+721+907+922
print("accuracy: ", correct*100/len(y1))
# Out:
# accuracy:  71.5

# %%
#with densenet
mapping={
    0:6,
    1:5,
    2:7,
    3:9,
    4:4,
    5:0,
    6:3,
    7:8,
    8:1,
    9:2
}
correct=698+904+643+787+324+479+640+718+907+922
print("accuracy: ", correct/len(y1))
# Out:
# accuracy:  0.7022
